# %%
# lets start by getting the data
import csv
import math
import matplotlib.pyplot as plt
from collections import defaultdict
from collections import Counter
import urllib2
import json
import re
import os
import numpy as np
from datetime import datetime
import calendar
import json
from __future__  import division

# %%
# Get data line by line from tmdb-5000-movie-database and save the data as dictionary
filepath = r"C:\Users\helga\Dropbox\Ingvar\FinalProject\Data\tmdb-5000-movie-dataset\tmdb_5000_credits.csv"
tmdb_5000_credits = defaultdict(dict)

with open(filepath) as csvfile:
    reader = csv.DictReader(csvfile, delimiter=",")
    for row in reader:
        tmdb_5000_credits[row["title"]] = row
        # put the lists and dictonaries to a correct format, (that is not as string)
        tmdb_5000_credits[row["title"]]['cast'] = json.loads(tmdb_5000_credits[row["title"]]['cast'])
        tmdb_5000_credits[row["title"]]['crew'] = json.loads(tmdb_5000_credits[row["title"]]['crew'])

# %%
for title in sorted(tmdb_5000_credits.keys()):
    title = title.replace(" ","-").replace("(","").replace(")","")

# %%
# Get data line by line from tmdb-5000-movie-database and save the data as dictionary

filepath = r"C:\Users\helga\Dropbox\Ingvar\FinalProject\Data\tmdb-5000-movie-dataset\tmdb_5000_movies.csv"
tmdb_5000_movies = defaultdict(dict)

with open(filepath) as csvfile:
    reader = csv.DictReader(csvfile, delimiter=",")
    for row in reader:
        tmdb_5000_movies[row["title"]] = row
        # put the lists and dictonaries to a correct format, (that is not as string)
        tmdb_5000_movies[row["title"]]['genres'] = json.loads(tmdb_5000_movies[row["title"]]['genres'])
        tmdb_5000_movies[row["title"]]['keywords'] = json.loads(tmdb_5000_movies[row["title"]]['keywords'])
        tmdb_5000_movies[row["title"]]['production_companies'] = json.loads(tmdb_5000_movies[row["title"]]['production_companies'])
        
for title in sorted(tmdb_5000_movies.keys()):
    title = title.replace(" ","-").replace("(","").replace(")","")

# %% [markdown]
# ### Lets find the covariance between vote_average and budget, of the films

# %%
vote_average_budget = [] # tuples of vote_averages and budget for each movie
for title in tmdb_5000_movies.keys():
    # we treat movie´s with less than 300 vote count as noise
    if float(tmdb_5000_movies[title]['vote_count'])  > 300:
        budget = float(tmdb_5000_movies[title]['budget'])
        vote_average = float(tmdb_5000_movies[title]['vote_average'])
        vote_average_budget.append((vote_average, budget))
    

vote_averages = []
budgets = []

# sort by rating since that is going to be our x-axis
for values in sorted(vote_average_budget):
    # if a movie has no budget, we treat it as noise
    if values[1] > 0:
        vote_averages.append(values[0])
        budgets.append(values[1])
    
   

# Lets plot the data
plt.plot(vote_averages, budgets, 'o', alpha = 0.5)
plt.title('Budgets versus Vote averages')
plt.xlabel('vote averages')
plt.ylabel('Budgets [dollars]')
plt.show()

# find the covariance:
print "The covariance between averge votes and the budget is: "
print np.corrcoef(vote_averages, budgets)
# Out:
# The covariance between averge votes and the budget is:
# [[ 1.         -0.13561858]
#  [-0.13561858  1.        ]]

# %% [markdown]
# ### The covariance between popularity and Relase Month

# %%
poopularity_date = [] # tuples of dates and popluarities in seconds for each movie
for title in tmdb_5000_movies.keys():
    popularity = float(tmdb_5000_movies[title]['popularity'])
    date = tmdb_5000_movies[title]['release_date'].split('-')
    # ensure we have a date and popularity for the film
    if len(date) > 1 and popularity > 0:
        month = int(date[1])
        poopularity_date.append((month, popularity))
    
months = []
popularities = []

# sort by date since that is going to be our x-axis
for values in sorted(poopularity_date):
    # collect the data for plotting
    months.append(values[0])
    popularities.append(values[1])


# Lets plot the data..
plt.plot(months, popularities, 'o', alpha = 0.5, color = 'maroon')
plt.title('Relase Month versus Popularity')
plt.xlabel('Months')
plt.ylabel('Popularity')
plt.xticks( range(1, 13), calendar.month_name[1:13], rotation=60 )
plt.show()

# find the covariance:
print "The covariance between averge votes and the budget is: "
print np.corrcoef(vote_averages, budgets)

# count the number of times a movie is relased in each month
months_count = Counter(months)
plt.plot(months_count.keys(), months_count.values(), color = 'maroon')
plt.title('Frequency of a movie relase')
plt.xlabel('Month')
plt.ylabel('Count')
plt.xticks( range(1, 13), calendar.month_name[1:13], rotation=60 )
plt.show()
# Out:
# The covariance between averge votes and the budget is:
# [[ 1.          0.63111374]
#  [ 0.63111374  1.        ]]

# %% [markdown]
# ### Covariance between Revenue and Budget

# %%
revenue_budget = [] # tuples of vote_averages and budget for each movie
for title in tmdb_5000_movies.keys():
    # we treat movie´s with less than 300 vote count as noise
    if float(tmdb_5000_movies[title]['vote_count'])  > 300:
        budget = float(tmdb_5000_movies[title]['budget'])
        revenue = float(tmdb_5000_movies[title]['revenue'])
        revenue_budget.append((revenue, budget))
    

revenues = []
budgets = []

# sort by rating since that is going to be our x-axis
for values in sorted(revenue_budget):
    # if a movie has no budget, we treat it as noise
    if values[1] > 0:
        revenues.append(values[0])
        budgets.append(values[1])
    
   

# Lets plot the data
plt.plot(revenues, budgets, 'o', alpha = 0.5, color = 'forestgreen')
plt.title('Revenue versus Budgets')
plt.xlabel('Revenue [dollors]')
plt.ylabel('Budgets [dollors]')
plt.show()

# find the covariance:
print "The covariance between averge votes and the budget is: "
print np.corrcoef(vote_averages, budgets)
# Out:
# The covariance between averge votes and the budget is:
# [[ 1.          0.63111374]
#  [ 0.63111374  1.        ]]

# %%
tmdb_5000_credits['Avatar']
# Out:
# {'cast': [{u'cast_id': 242,
#    u'character': u'Jake Sully',
#    u'credit_id': u'5602a8a7c3a3685532001c9a',
#    u'gender': 2,
#    u'id': 65731,
#    u'name': u'Sam Worthington',
#    u'order': 0},
#   {u'cast_id': 3,
#    u'character': u'Neytiri',
#    u'credit_id': u'52fe48009251416c750ac9cb',
#    u'gender': 1,
#    u'id': 8691,
#    u'name': u'Zoe Saldana',
#    u'order': 1},
#   {u'cast_id': 25,
#    u'character': u'Dr. Grace Augustine',
#    u'credit_id': u'52fe48009251416c750aca39',
#    u'gender': 1,
#    u'id': 10205,
#    u'name': u'Sigourney Weaver',
#    u'order': 2},
#   {u'cast_id': 4,
#    u'character': u'Col. Quaritch',
#    u'credit_id': u'52fe48009251416c750ac9cf',
#    u'gender': 2,
#    u'id': 32747,
#    u'name': u'Stephen Lang',
#    u'order': 3},
#   {u'cast_id': 5,
#    u'character': u'Trudy Chacon',
#    u'credit_id': u'52fe48009251416c750ac9d3',
#    u'gender': 1,
#    u'id': 17647,
#    u'name': u'Michelle Rodriguez',
#    u'order': 4},
#   {u'cast_id': 8,
#    u'character': u'Selfridge',
#    u'credit_id': u'52fe48009251416c750ac9e1',
#    u'gender': 2,
#    u'id': 1771,
#    u'name': u'Giovanni Ribisi',
#    u'order': 5},
#   {u'cast_id': 7,
#    u'character': u'Norm Spellman',
#    u'credit_id': u'52fe48009251416c750ac9dd',
#    u'gender': 2,
#    u'id': 59231,
#    u'name': u'Joel David Moore',
#    u'order': 6},
#   {u'cast_id': 9,
#    u'character': u'Moat',
#    u'credit_id': u'52fe48009251416c750ac9e5',
#    u'gender': 1,
#    u'id': 30485,
#    u'name': u'CCH Pounder',
#    u'order': 7},
#   {u'cast_id': 11,
#    u'character': u'Eytukan',
#    u'credit_id': u'52fe48009251416c750ac9ed',
#    u'gender': 2,
#    u'id': 15853,
#    u'name': u'Wes Studi',
#    u'order': 8},
#   {u'cast_id': 10,
#    u'character': u"Tsu'Tey",
#    u'credit_id': u'52fe48009251416c750ac9e9',
#    u'gender': 2,
#    u'id': 10964,
#    u'name': u'Laz Alonso',
#    u'order': 9},
#   {u'cast_id': 12,
#    u'character': u'Dr. Max Patel',
#    u'credit_id': u'52fe48009251416c750ac9f1',
#    u'gender': 2,
#    u'id': 95697,
#    u'name': u'Dileep Rao',
#    u'order': 10},
#   {u'cast_id': 13,
#    u'character': u'Lyle Wainfleet',
#    u'credit_id': u'52fe48009251416c750ac9f5',
#    u'gender': 2,
#    u'id': 98215,
#    u'name': u'Matt Gerald',
#    u'order': 11},
#   {u'cast_id': 32,
#    u'character': u'Private Fike',
#    u'credit_id': u'52fe48009251416c750aca5b',
#    u'gender': 2,
#    u'id': 154153,
#    u'name': u'Sean Anthony Moran',
#    u'order': 12},
#   {u'cast_id': 33,
#    u'character': u'Cryo Vault Med Tech',
#    u'credit_id': u'52fe48009251416c750aca5f',
#    u'gender': 2,
#    u'id': 397312,
#    u'name': u'Jason Whyte',
#    u'order': 13},
#   {u'cast_id': 34,
#    u'character': u'Venture Star Crew Chief',
#    u'credit_id': u'52fe48009251416c750aca63',
#    u'gender': 2,
#    u'id': 42317,
#    u'name': u'Scott Lawrence',
#    u'order': 14},
#   {u'cast_id': 35,
#    u'character': u'Lock Up Trooper',
#    u'credit_id': u'52fe48009251416c750aca67',
#    u'gender': 2,
#    u'id': 986734,
#    u'name': u'Kelly Kilgour',
#    u'order': 15},
#   {u'cast_id': 36,
#    u'character': u'Shuttle Pilot',
#    u'credit_id': u'52fe48009251416c750aca6b',
#    u'gender': 0,
#    u'id': 1207227,
#    u'name': u'James Patrick Pitt',
#    u'order': 16},
#   {u'cast_id': 37,
#    u'character': u'Shuttle Co-Pilot',
#    u'credit_id': u'52fe48009251416c750aca6f',
#    u'gender': 0,
#    u'id': 1180936,
#    u'name': u'Sean Patrick Murphy',
#    u'order': 17},
#   {u'cast_id': 38,
#    u'character': u'Shuttle Crew Chief',
#    u'credit_id': u'52fe48009251416c750aca73',
#    u'gender': 2,
#    u'id': 1019578,
#    u'name': u'Peter Dillon',
#    u'order': 18},
#   {u'cast_id': 39,
#    u'character': u'Tractor Operator / Troupe',
#    u'credit_id': u'52fe48009251416c750aca77',
#    u'gender': 0,
#    u'id': 91443,
#    u'name': u'Kevin Dorman',
#    u'order': 19},
#   {u'cast_id': 40,
#    u'character': u'Dragon Gunship Pilot',
#    u'credit_id': u'52fe48009251416c750aca7b',
#    u'gender': 2,
#    u'id': 173391,
#    u'name': u'Kelson Henderson',
#    u'order': 20},
#   {u'cast_id': 41,
#    u'character': u'Dragon Gunship Gunner',
#    u'credit_id': u'52fe48009251416c750aca7f',
#    u'gender': 0,
#    u'id': 1207236,
#    u'name': u'David Van Horn',
#    u'order': 21},
#   {u'cast_id': 42,
#    u'character': u'Dragon Gunship Navigator',
#    u'credit_id': u'52fe48009251416c750aca83',
#    u'gender': 0,
#    u'id': 215913,
#    u'name': u'Jacob Tomuri',
#    u'order': 22},
#   {u'cast_id': 43,
#    u'character': u'Suit #1',
#    u'credit_id': u'52fe48009251416c750aca87',
#    u'gender': 0,
#    u'id': 143206,
#    u'name': u'Michael Blain-Rozgay',
#    u'order': 23},
#   {u'cast_id': 44,
#    u'character': u'Suit #2',
#    u'credit_id': u'52fe48009251416c750aca8b',
#    u'gender': 2,
#    u'id': 169676,
#    u'name': u'Jon Curry',
#    u'order': 24},
#   {u'cast_id': 46,
#    u'character': u'Ambient Room Tech',
#    u'credit_id': u'52fe48009251416c750aca8f',
#    u'gender': 0,
#    u'id': 1048610,
#    u'name': u'Luke Hawker',
#    u'order': 25},
#   {u'cast_id': 47,
#    u'character': u'Ambient Room Tech / Troupe',
#    u'credit_id': u'52fe48009251416c750aca93',
#    u'gender': 0,
#    u'id': 42288,
#    u'name': u'Woody Schultz',
#    u'order': 26},
#   {u'cast_id': 48,
#    u'character': u'Horse Clan Leader',
#    u'credit_id': u'52fe48009251416c750aca97',
#    u'gender': 2,
#    u'id': 68278,
#    u'name': u'Peter Mensah',
#    u'order': 27},
#   {u'cast_id': 49,
#    u'character': u'Link Room Tech',
#    u'credit_id': u'52fe48009251416c750aca9b',
#    u'gender': 0,
#    u'id': 1207247,
#    u'name': u'Sonia Yee',
#    u'order': 28},
#   {u'cast_id': 50,
#    u'character': u'Basketball Avatar / Troupe',
#    u'credit_id': u'52fe48009251416c750aca9f',
#    u'gender': 1,
#    u'id': 1207248,
#    u'name': u'Jahnel Curfman',
#    u'order': 29},
#   {u'cast_id': 51,
#    u'character': u'Basketball Avatar',
#    u'credit_id': u'52fe48009251416c750acaa3',
#    u'gender': 0,
#    u'id': 89714,
#    u'name': u'Ilram Choi',
#    u'order': 30},
#   {u'cast_id': 52,
#    u'character': u"Na'vi Child",
#    u'credit_id': u'52fe48009251416c750acaa7',
#    u'gender': 0,
#    u'id': 1207249,
#    u'name': u'Kyla Warren',
#    u'order': 31},
#   {u'cast_id': 53,
#    u'character': u'Troupe',
#    u'credit_id': u'52fe48009251416c750acaab',
#    u'gender': 0,
#    u'id': 1207250,
#    u'name': u'Lisa Roumain',
#    u'order': 32},
#   {u'cast_id': 54,
#    u'character': u'Troupe',
#    u'credit_id': u'52fe48009251416c750acaaf',
#    u'gender': 1,
#    u'id': 83105,
#    u'name': u'Debra Wilson',
#    u'order': 33},
#   {u'cast_id': 57,
#    u'character': u'Troupe',
#    u'credit_id': u'52fe48009251416c750acabb',
#    u'gender': 0,
#    u'id': 1207253,
#    u'name': u'Chris Mala',
#    u'order': 34},
#   {u'cast_id': 55,
#    u'character': u'Troupe',
#    u'credit_id': u'52fe48009251416c750acab3',
#    u'gender': 0,
#    u'id': 1207251,
#    u'name': u'Taylor Kibby',
#    u'order': 35},
#   {u'cast_id': 56,
#    u'character': u'Troupe',
#    u'credit_id': u'52fe48009251416c750acab7',
#    u'gender': 0,
#    u'id': 1207252,
#    u'name': u'Jodie Landau',
#    u'order': 36},
#   {u'cast_id': 58,
#    u'character': u'Troupe',
#    u'credit_id': u'52fe48009251416c750acabf',
#    u'gender': 0,
#    u'id': 1207254,
#    u'name': u'Julie Lamm',
#    u'order': 37},
#   {u'cast_id': 59,
#    u'character': u'Troupe',
#    u'credit_id': u'52fe48009251416c750acac3',
#    u'gender': 0,
#    u'id': 1207257,
#    u'name': u'Cullen B. Madden',
#    u'order': 38},
#   {u'cast_id': 60,
#    u'character': u'Troupe',
#    u'credit_id': u'52fe48009251416c750acac7',
#    u'gender': 0,
#    u'id': 1207259,
#    u'name': u'Joseph Brady Madden',
#    u'order': 39},
#   {u'cast_id': 61,
#    u'character': u'Troupe',
#    u'credit_id': u'52fe48009251416c750acacb',
#    u'gender': 0,
#    u'id': 1207262,
#    u'name': u'Frankie Torres',
#    u'order': 40},
#   {u'cast_id': 62,
#    u'character': u'Troupe',
#    u'credit_id': u'52fe48009251416c750acacf',
#    u'gender': 1,
#    u'id': 1158600,
#    u'name': u'Austin Wilson',
#    u'order': 41},
#   {u'cast_id': 63,
#    u'character': u'Troupe',
#    u'credit_id': u'52fe48019251416c750acad3',
#    u'gender': 1,
#    u'id': 983705,
#    u'name': u'Sara Wilson',
#    u'order': 42},
#   {u'cast_id': 64,
#    u'character': u'Troupe',
#    u'credit_id': u'52fe48019251416c750acad7',
#    u'gender': 0,
#    u'id': 1207263,
#    u'name': u'Tamica Washington-Miller',
#    u'order': 43},
#   {u'cast_id': 65,
#    u'character': u'Op Center Staff',
#    u'credit_id': u'52fe48019251416c750acadb',
#    u'gender': 1,
#    u'id': 1145098,
#    u'name': u'Lucy Briant',
#    u'order': 44},
#   {u'cast_id': 66,
#    u'character': u'Op Center Staff',
#    u'credit_id': u'52fe48019251416c750acadf',
#    u'gender': 2,
#    u'id': 33305,
#    u'name': u'Nathan Meister',
#    u'order': 45},
#   {u'cast_id': 67,
#    u'character': u'Op Center Staff',
#    u'credit_id': u'52fe48019251416c750acae3',
#    u'gender': 0,
#    u'id': 1207264,
#    u'name': u'Gerry Blair',
#    u'order': 46},
#   {u'cast_id': 68,
#    u'character': u'Op Center Staff',
#    u'credit_id': u'52fe48019251416c750acae7',
#    u'gender': 2,
#    u'id': 33311,
#    u'name': u'Matthew Chamberlain',
#    u'order': 47},
#   {u'cast_id': 69,
#    u'character': u'Op Center Staff',
#    u'credit_id': u'52fe48019251416c750acaeb',
#    u'gender': 0,
#    u'id': 1207265,
#    u'name': u'Paul Yates',
#    u'order': 48},
#   {u'cast_id': 70,
#    u'character': u'Op Center Duty Officer',
#    u'credit_id': u'52fe48019251416c750acaef',
#    u'gender': 0,
#    u'id': 1207266,
#    u'name': u'Wray Wilson',
#    u'order': 49},
#   {u'cast_id': 71,
#    u'character': u'Op Center Staff',
#    u'credit_id': u'52fe48019251416c750acaf3',
#    u'gender': 2,
#    u'id': 54492,
#    u'name': u'James Gaylyn',
#    u'order': 50},
#   {u'cast_id': 72,
#    u'character': u'Dancer',
#    u'credit_id': u'52fe48019251416c750acaf7',
#    u'gender': 0,
#    u'id': 1207267,
#    u'name': u'Melvin Leno Clark III',
#    u'order': 51},
#   {u'cast_id': 73,
#    u'character': u'Dancer',
#    u'credit_id': u'52fe48019251416c750acafb',
#    u'gender': 0,
#    u'id': 1207268,
#    u'name': u'Carvon Futrell',
#    u'order': 52},
#   {u'cast_id': 74,
#    u'character': u'Dancer',
#    u'credit_id': u'52fe48019251416c750acaff',
#    u'gender': 0,
#    u'id': 1207269,
#    u'name': u'Brandon Jelkes',
#    u'order': 53},
#   {u'cast_id': 75,
#    u'character': u'Dancer',
#    u'credit_id': u'52fe48019251416c750acb03',
#    u'gender': 0,
#    u'id': 1207270,
#    u'name': u'Micah Moch',
#    u'order': 54},
#   {u'cast_id': 76,
#    u'character': u'Dancer',
#    u'credit_id': u'52fe48019251416c750acb07',
#    u'gender': 0,
#    u'id': 1207271,
#    u'name': u'Hanniyah Muhammad',
#    u'order': 55},
#   {u'cast_id': 77,
#    u'character': u'Dancer',
#    u'credit_id': u'52fe48019251416c750acb0b',
#    u'gender': 0,
#    u'id': 1207272,
#    u'name': u'Christopher Nolen',
#    u'order': 56},
#   {u'cast_id': 78,
#    u'character': u'Dancer',
#    u'credit_id': u'52fe48019251416c750acb0f',
#    u'gender': 0,
#    u'id': 1207273,
#    u'name': u'Christa Oliver',
#    u'order': 57},
#   {u'cast_id': 79,
#    u'character': u'Dancer',
#    u'credit_id': u'52fe48019251416c750acb13',
#    u'gender': 0,
#    u'id': 1207274,
#    u'name': u'April Marie Thomas',
#    u'order': 58},
#   {u'cast_id': 80,
#    u'character': u'Dancer',
#    u'credit_id': u'52fe48019251416c750acb17',
#    u'gender': 0,
#    u'id': 1207275,
#    u'name': u'Bravita A. Threatt',
#    u'order': 59},
#   {u'cast_id': 81,
#    u'character': u'Mining Chief (uncredited)',
#    u'credit_id': u'52fe48019251416c750acb1b',
#    u'gender': 0,
#    u'id': 1207276,
#    u'name': u'Colin Bleasdale',
#    u'order': 60},
#   {u'cast_id': 82,
#    u'character': u'Veteran Miner (uncredited)',
#    u'credit_id': u'52fe48019251416c750acb1f',
#    u'gender': 0,
#    u'id': 107969,
#    u'name': u'Mike Bodnar',
#    u'order': 61},
#   {u'cast_id': 83,
#    u'character': u'Richard (uncredited)',
#    u'credit_id': u'52fe48019251416c750acb23',
#    u'gender': 0,
#    u'id': 1207278,
#    u'name': u'Matt Clayton',
#    u'order': 62},
#   {u'cast_id': 84,
#    u'character': u"Nav'i (uncredited)",
#    u'credit_id': u'52fe48019251416c750acb27',
#    u'gender': 1,
#    u'id': 147898,
#    u'name': u'Nicole Dionne',
#    u'order': 63},
#   {u'cast_id': 85,
#    u'character': u'Trooper (uncredited)',
#    u'credit_id': u'52fe48019251416c750acb2b',
#    u'gender': 0,
#    u'id': 1207280,
#    u'name': u'Jamie Harrison',
#    u'order': 64},
#   {u'cast_id': 86,
#    u'character': u'Trooper (uncredited)',
#    u'credit_id': u'52fe48019251416c750acb2f',
#    u'gender': 0,
#    u'id': 1207281,
#    u'name': u'Allan Henry',
#    u'order': 65},
#   {u'cast_id': 87,
#    u'character': u'Ground Technician (uncredited)',
#    u'credit_id': u'52fe48019251416c750acb33',
#    u'gender': 2,
#    u'id': 1207282,
#    u'name': u'Anthony Ingruber',
#    u'order': 66},
#   {u'cast_id': 88,
#    u'character': u'Flight Crew Mechanic (uncredited)',
#    u'credit_id': u'52fe48019251416c750acb37',
#    u'gender': 0,
#    u'id': 1207283,
#    u'name': u'Ashley Jeffery',
#    u'order': 67},
#   {u'cast_id': 14,
#    u'character': u'Samson Pilot',
#    u'credit_id': u'52fe48009251416c750ac9f9',
#    u'gender': 0,
#    u'id': 98216,
#    u'name': u'Dean Knowsley',
#    u'order': 68},
#   {u'cast_id': 89,
#    u'character': u'Trooper (uncredited)',
#    u'credit_id': u'52fe48019251416c750acb3b',
#    u'gender': 0,
#    u'id': 1201399,
#    u'name': u'Joseph Mika-Hunt',
#    u'order': 69},
#   {u'cast_id': 90,
#    u'character': u'Banshee (uncredited)',
#    u'credit_id': u'52fe48019251416c750acb3f',
#    u'gender': 0,
#    u'id': 236696,
#    u'name': u'Terry Notary',
#    u'order': 70},
#   {u'cast_id': 91,
#    u'character': u'Soldier (uncredited)',
#    u'credit_id': u'52fe48019251416c750acb43',
#    u'gender': 0,
#    u'id': 1207287,
#    u'name': u'Kai Pantano',
#    u'order': 71},
#   {u'cast_id': 92,
#    u'character': u'Blast Technician (uncredited)',
#    u'credit_id': u'52fe48019251416c750acb47',
#    u'gender': 0,
#    u'id': 1207288,
#    u'name': u'Logan Pithyou',
#    u'order': 72},
#   {u'cast_id': 93,
#    u'character': u'Vindum Raah (uncredited)',
#    u'credit_id': u'52fe48019251416c750acb4b',
#    u'gender': 0,
#    u'id': 1207289,
#    u'name': u'Stuart Pollock',
#    u'order': 73},
#   {u'cast_id': 94,
#    u'character': u'Hero (uncredited)',
#    u'credit_id': u'52fe48019251416c750acb4f',
#    u'gender': 0,
#    u'id': 584868,
#    u'name': u'Raja',
#    u'order': 74},
#   {u'cast_id': 95,
#    u'character': u'Ops Centreworker (uncredited)',
#    u'credit_id': u'52fe48019251416c750acb53',
#    u'gender': 0,
#    u'id': 1207290,
#    u'name': u'Gareth Ruck',
#    u'order': 75},
#   {u'cast_id': 96,
#    u'character': u'Engineer (uncredited)',
#    u'credit_id': u'52fe48019251416c750acb57',
#    u'gender': 0,
#    u'id': 1062463,
#    u'name': u'Rhian Sheehan',
#    u'order': 76},
#   {u'cast_id': 97,
#    u'character': u"Col. Quaritch's Mech Suit (uncredited)",
#    u'credit_id': u'52fe48019251416c750acb5b',
#    u'gender': 0,
#    u'id': 60656,
#    u'name': u'T. J. Storm',
#    u'order': 77},
#   {u'cast_id': 98,
#    u'character': u'Female Marine (uncredited)',
#    u'credit_id': u'52fe48019251416c750acb5f',
#    u'gender': 0,
#    u'id': 1207291,
#    u'name': u'Jodie Taylor',
#    u'order': 78},
#   {u'cast_id': 99,
#    u'character': u'Ikran Clan Leader (uncredited)',
#    u'credit_id': u'52fe48019251416c750acb63',
#    u'gender': 1,
#    u'id': 1186027,
#    u'name': u'Alicia Vela-Bailey',
#    u'order': 79},
#   {u'cast_id': 100,
#    u'character': u'Geologist (uncredited)',
#    u'credit_id': u'52fe48019251416c750acb67',
#    u'gender': 0,
#    u'id': 1207292,
#    u'name': u'Richard Whiteside',
#    u'order': 80},
#   {u'cast_id': 101,
#    u'character': u"Na'vi (uncredited)",
#    u'credit_id': u'52fe48019251416c750acb6b',
#    u'gender': 0,
#    u'id': 103259,
#    u'name': u'Nikie Zambo',
#    u'order': 81},
#   {u'cast_id': 102,
#    u'character': u'Ambient Room Tech / Troupe',
#    u'credit_id': u'52fe48019251416c750acb6f',
#    u'gender': 1,
#    u'id': 42286,
#    u'name': u'Julene Renee',
#    u'order': 82}],
#  'crew': [{u'credit_id': u'52fe48009251416c750aca23',
#    u'department': u'Editing',
#    u'gender': 0,
#    u'id': 1721,
#    u'job': u'Editor',
#    u'name': u'Stephen E. Rivkin'},
#   {u'credit_id': u'539c47ecc3a36810e3001f87',
#    u'department': u'Art',
#    u'gender': 2,
#    u'id': 496,
#    u'job': u'Production Design',
#    u'name': u'Rick Carter'},
#   {u'credit_id': u'54491c89c3a3680fb4001cf7',
#    u'department': u'Sound',
#    u'gender': 0,
#    u'id': 900,
#    u'job': u'Sound Designer',
#    u'name': u'Christopher Boyes'},
#   {u'credit_id': u'54491cb70e0a267480001bd0',
#    u'department': u'Sound',
#    u'gender': 0,
#    u'id': 900,
#    u'job': u'Supervising Sound Editor',
#    u'name': u'Christopher Boyes'},
#   {u'credit_id': u'539c4a4cc3a36810c9002101',
#    u'department': u'Production',
#    u'gender': 1,
#    u'id': 1262,
#    u'job': u'Casting',
#    u'name': u'Mali Finn'},
#   {u'credit_id': u'5544ee3b925141499f0008fc',
#    u'department': u'Sound',
#    u'gender': 2,
#    u'id': 1729,
#    u'job': u'Original Music Composer',
#    u'name': u'James Horner'},
#   {u'credit_id': u'52fe48009251416c750ac9c3',
#    u'department': u'Directing',
#    u'gender': 2,
#    u'id': 2710,
#    u'job': u'Director',
#    u'name': u'James Cameron'},
#   {u'credit_id': u'52fe48009251416c750ac9d9',
#    u'department': u'Writing',
#    u'gender': 2,
#    u'id': 2710,
#    u'job': u'Writer',
#    u'name': u'James Cameron'},
#   {u'credit_id': u'52fe48009251416c750aca17',
#    u'department': u'Editing',
#    u'gender': 2,
#    u'id': 2710,
#    u'job': u'Editor',
#    u'name': u'James Cameron'},
#   {u'credit_id': u'52fe48009251416c750aca29',
#    u'department': u'Production',
#    u'gender': 2,
#    u'id': 2710,
#    u'job': u'Producer',
#    u'name': u'James Cameron'},
#   {u'credit_id': u'52fe48009251416c750aca3f',
#    u'department': u'Writing',
#    u'gender': 2,
#    u'id': 2710,
#    u'job': u'Screenplay',
#    u'name': u'James Cameron'},
#   {u'credit_id': u'539c4987c3a36810ba0021a4',
#    u'department': u'Art',
#    u'gender': 2,
#    u'id': 7236,
#    u'job': u'Art Direction',
#    u'name': u'Andrew Menzies'},
#   {u'credit_id': u'549598c3c3a3686ae9004383',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 6690,
#    u'job': u'Visual Effects Producer',
#    u'name': u'Jill Brooks'},
#   {u'credit_id': u'52fe48009251416c750aca4b',
#    u'department': u'Production',
#    u'gender': 1,
#    u'id': 6347,
#    u'job': u'Casting',
#    u'name': u'Margery Simkin'},
#   {u'credit_id': u'570b6f419251417da70032fe',
#    u'department': u'Art',
#    u'gender': 2,
#    u'id': 6878,
#    u'job': u'Supervising Art Director',
#    u'name': u'Kevin Ishioka'},
#   {u'credit_id': u'5495a0fac3a3686ae9004468',
#    u'department': u'Sound',
#    u'gender': 0,
#    u'id': 6883,
#    u'job': u'Music Editor',
#    u'name': u'Dick Bernstein'},
#   {u'credit_id': u'54959706c3a3686af3003e81',
#    u'department': u'Sound',
#    u'gender': 0,
#    u'id': 8159,
#    u'job': u'Sound Effects Editor',
#    u'name': u'Shannon Mills'},
#   {u'credit_id': u'54491d58c3a3680fb1001ccb',
#    u'department': u'Sound',
#    u'gender': 0,
#    u'id': 8160,
#    u'job': u'Foley',
#    u'name': u'Dennie Thorpe'},
#   {u'credit_id': u'54491d6cc3a3680fa5001b2c',
#    u'department': u'Sound',
#    u'gender': 0,
#    u'id': 8163,
#    u'job': u'Foley',
#    u'name': u'Jana Vance'},
#   {u'credit_id': u'52fe48009251416c750aca57',
#    u'department': u'Costume & Make-Up',
#    u'gender': 1,
#    u'id': 8527,
#    u'job': u'Costume Design',
#    u'name': u'Deborah Lynn Scott'},
#   {u'credit_id': u'52fe48009251416c750aca2f',
#    u'department': u'Production',
#    u'gender': 2,
#    u'id': 8529,
#    u'job': u'Producer',
#    u'name': u'Jon Landau'},
#   {u'credit_id': u'539c4937c3a36810ba002194',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 9618,
#    u'job': u'Art Direction',
#    u'name': u'Sean Haworth'},
#   {u'credit_id': u'539c49b6c3a36810c10020e6',
#    u'department': u'Art',
#    u'gender': 1,
#    u'id': 12653,
#    u'job': u'Set Decoration',
#    u'name': u'Kim Sinclair'},
#   {u'credit_id': u'570b6f2f9251413a0e00020d',
#    u'department': u'Art',
#    u'gender': 1,
#    u'id': 12653,
#    u'job': u'Supervising Art Director',
#    u'name': u'Kim Sinclair'},
#   {u'credit_id': u'54491a6c0e0a26748c001b19',
#    u'department': u'Art',
#    u'gender': 2,
#    u'id': 14350,
#    u'job': u'Set Designer',
#    u'name': u'Richard F. Mays'},
#   {u'credit_id': u'56928cf4c3a3684cff0025c4',
#    u'department': u'Production',
#    u'gender': 1,
#    u'id': 20294,
#    u'job': u'Executive Producer',
#    u'name': u'Laeta Kalogridis'},
#   {u'credit_id': u'52fe48009251416c750aca51',
#    u'department': u'Costume & Make-Up',
#    u'gender': 0,
#    u'id': 17675,
#    u'job': u'Costume Design',
#    u'name': u'Mayes C. Rubeo'},
#   {u'credit_id': u'52fe48009251416c750aca11',
#    u'department': u'Camera',
#    u'gender': 2,
#    u'id': 18265,
#    u'job': u'Director of Photography',
#    u'name': u'Mauro Fiore'},
#   {u'credit_id': u'5449194d0e0a26748f001b39',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 42281,
#    u'job': u'Set Designer',
#    u'name': u'Scott Herbertson'},
#   {u'credit_id': u'52fe48009251416c750aca05',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 42288,
#    u'job': u'Stunts',
#    u'name': u'Woody Schultz'},
#   {u'credit_id': u'5592aefb92514152de0010f5',
#    u'department': u'Costume & Make-Up',
#    u'gender': 0,
#    u'id': 29067,
#    u'job': u'Makeup Artist',
#    u'name': u'Linda DeVetta'},
#   {u'credit_id': u'5592afa492514152de00112c',
#    u'department': u'Costume & Make-Up',
#    u'gender': 0,
#    u'id': 29067,
#    u'job': u'Hairstylist',
#    u'name': u'Linda DeVetta'},
#   {u'credit_id': u'54959ed592514130fc002e5d',
#    u'department': u'Camera',
#    u'gender': 2,
#    u'id': 33302,
#    u'job': u'Camera Operator',
#    u'name': u'Richard Bluck'},
#   {u'credit_id': u'539c4891c3a36810ba002147',
#    u'department': u'Art',
#    u'gender': 2,
#    u'id': 33303,
#    u'job': u'Art Direction',
#    u'name': u'Simon Bright'},
#   {u'credit_id': u'54959c069251417a81001f3a',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 113145,
#    u'job': u'Visual Effects Supervisor',
#    u'name': u'Richard Martin'},
#   {u'credit_id': u'54959a0dc3a3680ff5002c8d',
#    u'department': u'Crew',
#    u'gender': 2,
#    u'id': 58188,
#    u'job': u'Visual Effects Editor',
#    u'name': u'Steve R. Moore'},
#   {u'credit_id': u'52fe48009251416c750aca1d',
#    u'department': u'Editing',
#    u'gender': 2,
#    u'id': 58871,
#    u'job': u'Editor',
#    u'name': u'John Refoua'},
#   {u'credit_id': u'54491a4dc3a3680fc30018ca',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 92359,
#    u'job': u'Set Designer',
#    u'name': u'Karl J. Martin'},
#   {u'credit_id': u'52fe48009251416c750aca35',
#    u'department': u'Camera',
#    u'gender': 1,
#    u'id': 72201,
#    u'job': u'Director of Photography',
#    u'name': u'Chiling Lin'},
#   {u'credit_id': u'52fe48009251416c750ac9ff',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 89714,
#    u'job': u'Stunts',
#    u'name': u'Ilram Choi'},
#   {u'credit_id': u'54959c529251416e2b004394',
#    u'department': u'Visual Effects',
#    u'gender': 2,
#    u'id': 93214,
#    u'job': u'Visual Effects Supervisor',
#    u'name': u'Steven Quale'},
#   {u'credit_id': u'54491edf0e0a267489001c37',
#    u'department': u'Crew',
#    u'gender': 1,
#    u'id': 122607,
#    u'job': u'Dialect Coach',
#    u'name': u'Carla Meyer'},
#   {u'credit_id': u'539c485bc3a368653d001a3a',
#    u'department': u'Art',
#    u'gender': 2,
#    u'id': 132585,
#    u'job': u'Art Direction',
#    u'name': u'Nick Bassett'},
#   {u'credit_id': u'539c4903c3a368653d001a74',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 132596,
#    u'job': u'Art Direction',
#    u'name': u'Jill Cormack'},
#   {u'credit_id': u'539c4967c3a368653d001a94',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 132604,
#    u'job': u'Art Direction',
#    u'name': u'Andy McLaren'},
#   {u'credit_id': u'52fe48009251416c750aca45',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 236696,
#    u'job': u'Motion Capture Artist',
#    u'name': u'Terry Notary'},
#   {u'credit_id': u'54959e02c3a3680fc60027d2',
#    u'department': u'Crew',
#    u'gender': 2,
#    u'id': 956198,
#    u'job': u'Stunt Coordinator',
#    u'name': u'Garrett Warren'},
#   {u'credit_id': u'54959ca3c3a3686ae300438c',
#    u'department': u'Visual Effects',
#    u'gender': 2,
#    u'id': 957874,
#    u'job': u'Visual Effects Supervisor',
#    u'name': u'Jonathan Rothbart'},
#   {u'credit_id': u'570b6f519251412c74001b2f',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 957889,
#    u'job': u'Supervising Art Director',
#    u'name': u'Stefan Dechant'},
#   {u'credit_id': u'570b6f62c3a3680b77007460',
#    u'department': u'Art',
#    u'gender': 2,
#    u'id': 959555,
#    u'job': u'Supervising Art Director',
#    u'name': u'Todd Cherniawsky'},
#   {u'credit_id': u'539c4a3ac3a36810da0021cc',
#    u'department': u'Production',
#    u'gender': 0,
#    u'id': 1016177,
#    u'job': u'Casting',
#    u'name': u'Miranda Rivers'},
#   {u'credit_id': u'539c482cc3a36810c1002062',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 1032536,
#    u'job': u'Production Design',
#    u'name': u'Robert Stromberg'},
#   {u'credit_id': u'539c4b65c3a36810c9002125',
#    u'department': u'Costume & Make-Up',
#    u'gender': 2,
#    u'id': 1071680,
#    u'job': u'Costume Design',
#    u'name': u'John Harding'},
#   {u'credit_id': u'54959e6692514130fc002e4e',
#    u'department': u'Camera',
#    u'gender': 0,
#    u'id': 1177364,
#    u'job': u'Steadicam Operator',
#    u'name': u'Roberto De Angelis'},
#   {u'credit_id': u'539c49f1c3a368653d001aac',
#    u'department': u'Costume & Make-Up',
#    u'gender': 2,
#    u'id': 1202850,
#    u'job': u'Makeup Department Head',
#    u'name': u'Mike Smithson'},
#   {u'credit_id': u'5495999ec3a3686ae100460c',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 1204668,
#    u'job': u'Visual Effects Producer',
#    u'name': u'Alain Lalanne'},
#   {u'credit_id': u'54959cdfc3a3681153002729',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 1206410,
#    u'job': u'Visual Effects Supervisor',
#    u'name': u'Lucas Salton'},
#   {u'credit_id': u'549596239251417a81001eae',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1234266,
#    u'job': u'Post Production Supervisor',
#    u'name': u'Janace Tashjian'},
#   {u'credit_id': u'54959c859251416e1e003efe',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 1271932,
#    u'job': u'Visual Effects Supervisor',
#    u'name': u'Stephen Rosenbaum'},
#   {u'credit_id': u'5592af28c3a368775a00105f',
#    u'department': u'Costume & Make-Up',
#    u'gender': 0,
#    u'id': 1310064,
#    u'job': u'Makeup Artist',
#    u'name': u'Frankie Karena'},
#   {u'credit_id': u'539c4adfc3a36810e300203b',
#    u'department': u'Costume & Make-Up',
#    u'gender': 1,
#    u'id': 1319844,
#    u'job': u'Costume Supervisor',
#    u'name': u'Lisa Lovaas'},
#   {u'credit_id': u'54959b579251416e2b004371',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 1327028,
#    u'job': u'Visual Effects Supervisor',
#    u'name': u'Jonathan Fawkner'},
#   {u'credit_id': u'539c48a7c3a36810b5001fa7',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 1330561,
#    u'job': u'Art Direction',
#    u'name': u'Robert Bavin'},
#   {u'credit_id': u'539c4a71c3a36810da0021e0',
#    u'department': u'Costume & Make-Up',
#    u'gender': 0,
#    u'id': 1330567,
#    u'job': u'Costume Supervisor',
#    u'name': u'Anthony Almaraz'},
#   {u'credit_id': u'539c4a8ac3a36810ba0021e4',
#    u'department': u'Costume & Make-Up',
#    u'gender': 0,
#    u'id': 1330570,
#    u'job': u'Costume Supervisor',
#    u'name': u'Carolyn M. Fenton'},
#   {u'credit_id': u'539c4ab6c3a36810da0021f0',
#    u'department': u'Costume & Make-Up',
#    u'gender': 0,
#    u'id': 1330574,
#    u'job': u'Costume Supervisor',
#    u'name': u'Beth Koenigsberg'},
#   {u'credit_id': u'54491ab70e0a267480001ba2',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 1336191,
#    u'job': u'Set Designer',
#    u'name': u'Sam Page'},
#   {u'credit_id': u'544919d9c3a3680fc30018bd',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 1339441,
#    u'job': u'Set Designer',
#    u'name': u'Tex Kadonaga'},
#   {u'credit_id': u'54491cf50e0a267483001b0c',
#    u'department': u'Editing',
#    u'gender': 0,
#    u'id': 1352422,
#    u'job': u'Dialogue Editor',
#    u'name': u'Kim Foscato'},
#   {u'credit_id': u'544919f40e0a26748c001b09',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 1352962,
#    u'job': u'Set Designer',
#    u'name': u'Tammy S. Lee'},
#   {u'credit_id': u'5495a115c3a3680ff5002d71',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1357070,
#    u'job': u'Transportation Coordinator',
#    u'name': u'Denny Caira'},
#   {u'credit_id': u'5495a12f92514130fc002e94',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1357071,
#    u'job': u'Transportation Coordinator',
#    u'name': u'James Waitkus'},
#   {u'credit_id': u'5495976fc3a36811530026b0',
#    u'department': u'Sound',
#    u'gender': 0,
#    u'id': 1360103,
#    u'job': u'Supervising Sound Editor',
#    u'name': u'Addison Teague'},
#   {u'credit_id': u'54491837c3a3680fb1001c5a',
#    u'department': u'Art',
#    u'gender': 2,
#    u'id': 1376887,
#    u'job': u'Set Designer',
#    u'name': u'C. Scott Baker'},
#   {u'credit_id': u'54491878c3a3680fb4001c9d',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 1376888,
#    u'job': u'Set Designer',
#    u'name': u'Luke Caska'},
#   {u'credit_id': u'544918dac3a3680fa5001ae0',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 1376889,
#    u'job': u'Set Designer',
#    u'name': u'David Chow'},
#   {u'credit_id': u'544919110e0a267486001b68',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 1376890,
#    u'job': u'Set Designer',
#    u'name': u'Jonathan Dyer'},
#   {u'credit_id': u'54491967c3a3680faa001b5e',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 1376891,
#    u'job': u'Set Designer',
#    u'name': u'Joseph Hiura'},
#   {u'credit_id': u'54491997c3a3680fb1001c8a',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 1376892,
#    u'job': u'Art Department Coordinator',
#    u'name': u'Rebecca Jellie'},
#   {u'credit_id': u'544919ba0e0a26748f001b42',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 1376893,
#    u'job': u'Set Designer',
#    u'name': u'Robert Andrew Johnson'},
#   {u'credit_id': u'54491b1dc3a3680faa001b8c',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 1376895,
#    u'job': u'Assistant Art Director',
#    u'name': u'Mike Stassi'},
#   {u'credit_id': u'54491b79c3a3680fbb001826',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 1376897,
#    u'job': u'Construction Coordinator',
#    u'name': u'John Villarino'},
#   {u'credit_id': u'54491baec3a3680fb4001ce6',
#    u'department': u'Art',
#    u'gender': 2,
#    u'id': 1376898,
#    u'job': u'Assistant Art Director',
#    u'name': u'Jeffrey Wisniewski'},
#   {u'credit_id': u'54491d2fc3a3680fb4001d07',
#    u'department': u'Editing',
#    u'gender': 0,
#    u'id': 1376899,
#    u'job': u'Dialogue Editor',
#    u'name': u'Cheryl Nardi'},
#   {u'credit_id': u'54491d86c3a3680fa5001b2f',
#    u'department': u'Editing',
#    u'gender': 0,
#    u'id': 1376901,
#    u'job': u'Dialogue Editor',
#    u'name': u'Marshall Winn'},
#   {u'credit_id': u'54491d9dc3a3680faa001bb0',
#    u'department': u'Sound',
#    u'gender': 0,
#    u'id': 1376902,
#    u'job': u'Supervising Sound Editor',
#    u'name': u'Gwendolyn Yates Whittle'},
#   {u'credit_id': u'54491dc10e0a267486001bce',
#    u'department': u'Sound',
#    u'gender': 0,
#    u'id': 1376903,
#    u'job': u'Sound Re-Recording Mixer',
#    u'name': u'William Stein'},
#   {u'credit_id': u'54491f500e0a26747c001c07',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1376909,
#    u'job': u'Choreographer',
#    u'name': u'Lula Washington'},
#   {u'credit_id': u'549599239251412c4e002a2e',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 1391692,
#    u'job': u'Visual Effects Producer',
#    u'name': u'Chris Del Conte'},
#   {u'credit_id': u'54959d54c3a36831b8001d9a',
#    u'department': u'Visual Effects',
#    u'gender': 2,
#    u'id': 1391695,
#    u'job': u'Visual Effects Supervisor',
#    u'name': u'R. Christopher White'},
#   {u'credit_id': u'54959bdf9251412c4e002a66',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 1394070,
#    u'job': u'Visual Effects Supervisor',
#    u'name': u'Dan Lemmon'},
#   {u'credit_id': u'5495971d92514132ed002922',
#    u'department': u'Sound',
#    u'gender': 0,
#    u'id': 1394129,
#    u'job': u'Sound Effects Editor',
#    u'name': u'Tim Nielsen'},
#   {u'credit_id': u'5592b25792514152cc0011aa',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1394286,
#    u'job': u'CG Supervisor',
#    u'name': u'Michael Mulholland'},
#   {u'credit_id': u'54959a329251416e2b004355',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1394750,
#    u'job': u'Visual Effects Editor',
#    u'name': u'Thomas Nittmann'},
#   {u'credit_id': u'54959d6dc3a3686ae9004401',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 1394755,
#    u'job': u'Visual Effects Supervisor',
#    u'name': u'Edson Williams'},
#   {u'credit_id': u'5495a08fc3a3686ae300441c',
#    u'department': u'Editing',
#    u'gender': 0,
#    u'id': 1394953,
#    u'job': u'Digital Intermediate',
#    u'name': u'Christine Carr'},
#   {u'credit_id': u'55402d659251413d6d000249',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 1395269,
#    u'job': u'Visual Effects Supervisor',
#    u'name': u'John Bruno'},
#   {u'credit_id': u'54959e7b9251416e1e003f3e',
#    u'department': u'Camera',
#    u'gender': 0,
#    u'id': 1398970,
#    u'job': u'Steadicam Operator',
#    u'name': u'David Emmerichs'},
#   {u'credit_id': u'54959734c3a3686ae10045e0',
#    u'department': u'Sound',
#    u'gender': 0,
#    u'id': 1400906,
#    u'job': u'Sound Effects Editor',
#    u'name': u'Christopher Scarabosio'},
#   {u'credit_id': u'549595dd92514130fc002d79',
#    u'department': u'Production',
#    u'gender': 0,
#    u'id': 1401784,
#    u'job': u'Production Supervisor',
#    u'name': u'Jennifer Teves'},
#   {u'credit_id': u'549596009251413af70028cc',
#    u'department': u'Production',
#    u'gender': 0,
#    u'id': 1401785,
#    u'job': u'Production Manager',
#    u'name': u'Brigitte Yorke'},
#   {u'credit_id': u'549596e892514130fc002d99',
#    u'department': u'Sound',
#    u'gender': 0,
#    u'id': 1401786,
#    u'job': u'Sound Effects Editor',
#    u'name': u'Ken Fischer'},
#   {u'credit_id': u'549598229251412c4e002a1c',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1401787,
#    u'job': u'Special Effects Coordinator',
#    u'name': u'Iain Hutton'},
#   {u'credit_id': u'549598349251416e2b00432b',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1401788,
#    u'job': u'Special Effects Coordinator',
#    u'name': u'Steve Ingram'},
#   {u'credit_id': u'54959905c3a3686ae3004324',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 1401789,
#    u'job': u'Visual Effects Producer',
#    u'name': u'Joyce Cox'},
#   {u'credit_id': u'5495994b92514132ed002951',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 1401790,
#    u'job': u'Visual Effects Producer',
#    u'name': u'Jenny Foster'},
#   {u'credit_id': u'549599cbc3a3686ae1004613',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1401791,
#    u'job': u'Visual Effects Editor',
#    u'name': u'Christopher Marino'},
#   {u'credit_id': u'549599f2c3a3686ae100461e',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1401792,
#    u'job': u'Visual Effects Editor',
#    u'name': u'Jim Milton'},
#   {u'credit_id': u'54959a51c3a3686af3003eb5',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 1401793,
#    u'job': u'Visual Effects Producer',
#    u'name': u'Cyndi Ochs'},
#   {u'credit_id': u'54959a7cc3a36811530026f4',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1401794,
#    u'job': u'Visual Effects Editor',
#    u'name': u'Lucas Putnam'},
#   {u'credit_id': u'54959b91c3a3680ff5002cb4',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 1401795,
#    u'job': u'Visual Effects Supervisor',
#    u'name': u"Anthony 'Max' Ivins"},
#   {u'credit_id': u'54959bb69251412c4e002a5f',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 1401796,
#    u'job': u'Visual Effects Supervisor',
#    u'name': u'John Knoll'},
#   {u'credit_id': u'54959cbbc3a3686ae3004391',
#    u'department': u'Visual Effects',
#    u'gender': 2,
#    u'id': 1401799,
#    u'job': u'Visual Effects Supervisor',
#    u'name': u'Eric Saindon'},
#   {u'credit_id': u'54959d06c3a3686ae90043f6',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 1401800,
#    u'job': u'Visual Effects Supervisor',
#    u'name': u'Wayne Stables'},
#   {u'credit_id': u'54959d259251416e1e003f11',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 1401801,
#    u'job': u'Visual Effects Supervisor',
#    u'name': u'David Stinnett'},
#   {u'credit_id': u'54959db49251413af7002975',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 1401803,
#    u'job': u'Visual Effects Supervisor',
#    u'name': u'Guy Williams'},
#   {u'credit_id': u'54959de4c3a3681153002750',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1401804,
#    u'job': u'Stunt Coordinator',
#    u'name': u'Stuart Thorp'},
#   {u'credit_id': u'54959ef2c3a3680fc60027f2',
#    u'department': u'Lighting',
#    u'gender': 0,
#    u'id': 1401805,
#    u'job': u'Best Boy Electric',
#    u'name': u'Giles Coburn'},
#   {u'credit_id': u'54959f07c3a3680fc60027f9',
#    u'department': u'Camera',
#    u'gender': 2,
#    u'id': 1401806,
#    u'job': u'Still Photographer',
#    u'name': u'Mark Fellman'},
#   {u'credit_id': u'54959f47c3a3681153002774',
#    u'department': u'Lighting',
#    u'gender': 0,
#    u'id': 1401807,
#    u'job': u'Lighting Technician',
#    u'name': u'Scott Sprague'},
#   {u'credit_id': u'54959f8cc3a36831b8001df2',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 1401808,
#    u'job': u'Animation Director',
#    u'name': u'Jeremy Hollobon'},
#   {u'credit_id': u'54959fa0c3a36831b8001dfb',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 1401809,
#    u'job': u'Animation Director',
#    u'name': u'Orlando Meunier'},
#   {u'credit_id': u'54959fb6c3a3686af3003f54',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 1401810,
#    u'job': u'Animation Director',
#    u'name': u'Taisuke Tanimura'},
#   {u'credit_id': u'54959fd2c3a36831b8001e02',
#    u'department': u'Costume & Make-Up',
#    u'gender': 0,
#    u'id': 1401812,
#    u'job': u'Set Costumer',
#    u'name': u'Lilia Mishel Acevedo'},
#   {u'credit_id': u'54959ff9c3a3686ae300440c',
#    u'department': u'Costume & Make-Up',
#    u'gender': 0,
#    u'id': 1401814,
#    u'job': u'Set Costumer',
#    u'name': u'Alejandro M. Hernandez'},
#   {u'credit_id': u'5495a0ddc3a3686ae10046fe',
#    u'department': u'Editing',
#    u'gender': 0,
#    u'id': 1401815,
#    u'job': u'Digital Intermediate',
#    u'name': u'Marvin Hall'},
#   {u'credit_id': u'5495a1f7c3a3686ae3004443',
#    u'department': u'Production',
#    u'gender': 0,
#    u'id': 1401816,
#    u'job': u'Publicist',
#    u'name': u'Judy Alley'},
#   {u'credit_id': u'5592b29fc3a36869d100002f',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1418381,
#    u'job': u'CG Supervisor',
#    u'name': u'Mike Perry'},
#   {u'credit_id': u'5592b23a9251415df8001081',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1426854,
#    u'job': u'CG Supervisor',
#    u'name': u'Andrew Morley'},
#   {u'credit_id': u'55491e1192514104c40002d8',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 1438901,
#    u'job': u'Conceptual Design',
#    u'name': u'Seth Engstrom'},
#   {u'credit_id': u'5525d5809251417276002b06',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1447362,
#    u'job': u'Visual Effects Art Director',
#    u'name': u'Eric Oliver'},
#   {u'credit_id': u'554427ca925141586500312a',
#    u'department': u'Visual Effects',
#    u'gender': 0,
#    u'id': 1447503,
#    u'job': u'Modeling',
#    u'name': u'Matsune Suzuki'},
#   {u'credit_id': u'551906889251415aab001c88',
#    u'department': u'Art',
#    u'gender': 0,
#    u'id': 1447524,
#    u'job': u'Art Department Manager',
#    u'name': u'Paul Tobin'},
#   {u'credit_id': u'5592af8492514152cc0010de',
#    u'department': u'Costume & Make-Up',
#    u'gender': 0,
#    u'id': 1452643,
#    u'job': u'Hairstylist',
#    u'name': u'Roxane Griffin'},
#   {u'credit_id': u'553d3c109251415852001318',
#    u'department': u'Lighting',
#    u'gender': 0,
#    u'id': 1453938,
#    u'job': u'Lighting Artist',
#    u'name': u'Arun Ram-Mohan'},
#   {u'credit_id': u'5592af4692514152d5001355',
#    u'department': u'Costume & Make-Up',
#    u'gender': 0,
#    u'id': 1457305,
#    u'job': u'Makeup Artist',
#    u'name': u'Georgia Lockhart-Adams'},
#   {u'credit_id': u'5592b2eac3a36877470012a5',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1466035,
#    u'job': u'CG Supervisor',
#    u'name': u'Thrain Shadbolt'},
#   {u'credit_id': u'5592b032c3a36877450015f1',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1483220,
#    u'job': u'CG Supervisor',
#    u'name': u'Brad Alexander'},
#   {u'credit_id': u'5592b05592514152d80012f6',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1483221,
#    u'job': u'CG Supervisor',
#    u'name': u'Shadi Almassizadeh'},
#   {u'credit_id': u'5592b090c3a36877570010b5',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1483222,
#    u'job': u'CG Supervisor',
#    u'name': u'Simon Clutterbuck'},
#   {u'credit_id': u'5592b0dbc3a368774b00112c',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1483223,
#    u'job': u'CG Supervisor',
#    u'name': u'Graeme Demmocks'},
#   {u'credit_id': u'5592b0fe92514152db0010c1',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1483224,
#    u'job': u'CG Supervisor',
#    u'name': u'Adrian Fernandes'},
#   {u'credit_id': u'5592b11f9251415df8001059',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1483225,
#    u'job': u'CG Supervisor',
#    u'name': u'Mitch Gates'},
#   {u'credit_id': u'5592b15dc3a3687745001645',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1483226,
#    u'job': u'CG Supervisor',
#    u'name': u'Jerry Kung'},
#   {u'credit_id': u'5592b18e925141645a0004ae',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1483227,
#    u'job': u'CG Supervisor',
#    u'name': u'Andy Lomas'},
#   {u'credit_id': u'5592b1bfc3a368775d0010e7',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1483228,
#    u'job': u'CG Supervisor',
#    u'name': u'Sebastian Marino'},
#   {u'credit_id': u'5592b2049251415df8001078',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1483229,
#    u'job': u'CG Supervisor',
#    u'name': u'Matthias Menz'},
#   {u'credit_id': u'5592b27b92514152d800136a',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1483230,
#    u'job': u'CG Supervisor',
#    u'name': u'Sergei Nevshupov'},
#   {u'credit_id': u'5592b2c3c3a36869e800003c',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1483231,
#    u'job': u'CG Supervisor',
#    u'name': u'Philippe Rebours'},
#   {u'credit_id': u'5592b317c3a36877470012af',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1483232,
#    u'job': u'CG Supervisor',
#    u'name': u'Michael Takarangi'},
#   {u'credit_id': u'5592b345c3a36877470012bb',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1483233,
#    u'job': u'CG Supervisor',
#    u'name': u'David Weitzberg'},
#   {u'credit_id': u'5592b37cc3a368775100113b',
#    u'department': u'Crew',
#    u'gender': 0,
#    u'id': 1483234,
#    u'job': u'CG Supervisor',
#    u'name': u'Ben White'},
#   {u'credit_id': u'573c8e2f9251413f5d000094',
#    u'department': u'Crew',
#    u'gender': 1,
#    u'id': 1621932,
#    u'job': u'Stunts',
#    u'name': u'Min Windle'}],
#  'movie_id': '19995',
#  'title': 'Avatar'}

# %%
bla = json.loads(tmdb_5000_credits['Avatar']['cast'])
print bla[0]['name']
# Out:
# Sam Worthington

# %% [markdown]
# ### Revenue Versus Gender ratio

# %%
total_number_off_females = 0
total_number_off_males = 0
revenue_gender_ratio = [] # tuples of revenue and gender ratio
for title in tmdb_5000_credits.keys():
    number_of_males = 0
    number_of_females = 0
    for actor in tmdb_5000_credits[title]['cast']:
        # count how many females and males are in each movie
        gender_type = actor['gender']
        if gender_type == 1:
            number_of_females += 1
        elif gender_type == 2:
             number_of_males+= 1
        else:
            # if a person has no gender or gender is not specified we tread it as noise 
            pass
    total_number_off_females += number_of_females
    total_number_off_males += number_of_males
            
            
    # if both number of males and females is 0, we treat the data as noise, since we need to have actors  
    try: 
        revenue_gender_ratio.append(( number_of_females / (number_of_males + number_of_females), float(tmdb_5000_movies[title]['revenue'])))
        
    except  ZeroDivisionError:
        pass
    
    

gender_ratio = []
revenue = []

# sort the gender since it is going to be our x axis
for values in sorted(revenue_gender_ratio):
    gender_ratio.append(values[0])
    revenue.append(values[1])
    
# for color of the plots
t = range(len(gender_ratio))

plt.scatter(gender_ratio, revenue, c=t, cmap='cool', alpha = 0.5)
plt.title('Revenue vs Gender Ratio')
plt.xlabel('Gender Ratio')
plt.ylabel('Revenue')
plt.show()


print "Gender Ratio: The closer to the value 1, the bigger ratio of females"
print "Gender Ratio: The closer to the value 0, the bigger ratio of males"
# find the covariance:
print "The covariance between Revenue and the gender ratio is: "
print np.corrcoef(gender_ratio, revenue)

print
print '\033[1m' + 'Number of actors' # this is bold
print '\033[0m' # stops the boldness
print 'Number of females: {}'.format(total_number_off_females)
print 'Number of males: {}'.format(total_number_off_males)
print 'Total number of actors: {}'.format(total_number_off_males + total_number_off_females)
# Out:
# Gender Ratio: The closer to the value 1, the bigger ratio of females
# Gender Ratio: The closer to the value 0, the bigger ratio of males
# The covariance between Revenue and the gender ratio is:
# [[ 1.         -0.08249627]
#  [-0.08249627  1.        ]]
#
# Number of actors
#
# Number of females: 24158
# Number of males: 48264
# Total number of actors: 72422

# %% [markdown]
# ### Histogram of ratings

# %%
ratings = []
for title in tmdb_5000_movies.keys():
    # we do not accept vote average for fewer than 100 votes
    if float(tmdb_5000_movies[title]["vote_count"]) > 100:
        ratings.append(float(tmdb_5000_movies[title]["vote_average"]))

plt.figure(num=None, figsize=(14, 4), dpi=80, facecolor='w', edgecolor='k') 
plt.hist(ratings, color = 'hotpink', alpha = 0.8)
plt.xlabel('Rating value')
plt.ylabel('Number of ratings')
plt.title('Ratings of all movies')
# show all the posibilities
plt.xlim([0,10])
plt.show()

# %%
 tmdb_5000_movies['Avatar']
# Out:
# {'budget': '237000000',
#  'genres': '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]',
#  'homepage': 'http://www.avatarmovie.com/',
#  'id': '19995',
#  'keywords': '[{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"}, {"id": 3386, "name": "space war"}, {"id": 3388, "name": "space colony"}, {"id": 3679, "name": "society"}, {"id": 3801, "name": "space travel"}, {"id": 9685, "name": "futuristic"}, {"id": 9840, "name": "romance"}, {"id": 9882, "name": "space"}, {"id": 9951, "name": "alien"}, {"id": 10148, "name": "tribe"}, {"id": 10158, "name": "alien planet"}, {"id": 10987, "name": "cgi"}, {"id": 11399, "name": "marine"}, {"id": 13065, "name": "soldier"}, {"id": 14643, "name": "battle"}, {"id": 14720, "name": "love affair"}, {"id": 165431, "name": "anti war"}, {"id": 193554, "name": "power relations"}, {"id": 206690, "name": "mind and soul"}, {"id": 209714, "name": "3d"}]',
#  'original_language': 'en',
#  'original_title': 'Avatar',
#  'overview': 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.',
#  'popularity': '150.437577',
#  'production_companies': '[{"name": "Ingenious Film Partners", "id": 289}, {"name": "Twentieth Century Fox Film Corporation", "id": 306}, {"name": "Dune Entertainment", "id": 444}, {"name": "Lightstorm Entertainment", "id": 574}]',
#  'production_countries': '[{"iso_3166_1": "US", "name": "United States of America"}, {"iso_3166_1": "GB", "name": "United Kingdom"}]',
#  'release_date': '2009-12-10',
#  'revenue': '2787965087',
#  'runtime': '162',
#  'spoken_languages': '[{"iso_639_1": "en", "name": "English"}, {"iso_639_1": "es", "name": "Espa\\u00f1ol"}]',
#  'status': 'Released',
#  'tagline': 'Enter the World of Pandora.',
#  'title': 'Avatar',
#  'vote_average': '7.2',
#  'vote_count': '11800'}

# %% [markdown]
# ### Cout from each category

# %%
genres = []
for title in tmdb_5000_movies.keys():
    for names in tmdb_5000_movies[title]['genres']:
        # append all values for genre to the genres list
        genres.append(names['name'])
        
# get the count of all genres
number_in_genres = Counter(genres)


# get the data to plot
unique_genres = []
count = []
for key, value in number_in_genres.items():
    count.append(value)
    unique_genres.append(key)
    
plt.figure(num=None, figsize=(14, 4), dpi=80, facecolor='w', edgecolor='k')    
plt.bar(range(len(count)), count)
plt.xlabel('Categories')
plt.ylabel('Number of movies')
plt.title('Number of movies in each category')
plt.xticks( range(len(unique_genres)), unique_genres, rotation=60 )

plt.show()

# %%
number_in_genres
# Out:
# Counter({u'Action': 1152,
#          u'Adventure': 789,
#          u'Animation': 234,
#          u'Comedy': 1722,
#          u'Crime': 696,
#          u'Documentary': 110,
#          u'Drama': 2296,
#          u'Family': 513,
#          u'Fantasy': 423,
#          u'Foreign': 34,
#          u'History': 197,
#          u'Horror': 519,
#          u'Music': 185,
#          u'Mystery': 348,
#          u'Romance': 893,
#          u'Science Fiction': 534,
#          u'TV Movie': 8,
#          u'Thriller': 1273,
#          u'War': 144,
#          u'Western': 82})

# %%
tmdb_5000_movies['Avatar']
# Out:
# {'budget': '237000000',
#  'genres': [{u'id': 28, u'name': u'Action'},
#   {u'id': 12, u'name': u'Adventure'},
#   {u'id': 14, u'name': u'Fantasy'},
#   {u'id': 878, u'name': u'Science Fiction'}],
#  'homepage': 'http://www.avatarmovie.com/',
#  'id': '19995',
#  'keywords': [{u'id': 1463, u'name': u'culture clash'},
#   {u'id': 2964, u'name': u'future'},
#   {u'id': 3386, u'name': u'space war'},
#   {u'id': 3388, u'name': u'space colony'},
#   {u'id': 3679, u'name': u'society'},
#   {u'id': 3801, u'name': u'space travel'},
#   {u'id': 9685, u'name': u'futuristic'},
#   {u'id': 9840, u'name': u'romance'},
#   {u'id': 9882, u'name': u'space'},
#   {u'id': 9951, u'name': u'alien'},
#   {u'id': 10148, u'name': u'tribe'},
#   {u'id': 10158, u'name': u'alien planet'},
#   {u'id': 10987, u'name': u'cgi'},
#   {u'id': 11399, u'name': u'marine'},
#   {u'id': 13065, u'name': u'soldier'},
#   {u'id': 14643, u'name': u'battle'},
#   {u'id': 14720, u'name': u'love affair'},
#   {u'id': 165431, u'name': u'anti war'},
#   {u'id': 193554, u'name': u'power relations'},
#   {u'id': 206690, u'name': u'mind and soul'},
#   {u'id': 209714, u'name': u'3d'}],
#  'original_language': 'en',
#  'original_title': 'Avatar',
#  'overview': 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.',
#  'popularity': '150.437577',
#  'production_companies': [{u'id': 289, u'name': u'Ingenious Film Partners'},
#   {u'id': 306, u'name': u'Twentieth Century Fox Film Corporation'},
#   {u'id': 444, u'name': u'Dune Entertainment'},
#   {u'id': 574, u'name': u'Lightstorm Entertainment'}],
#  'production_countries': '[{"iso_3166_1": "US", "name": "United States of America"}, {"iso_3166_1": "GB", "name": "United Kingdom"}]',
#  'release_date': '2009-12-10',
#  'revenue': '2787965087',
#  'runtime': '162',
#  'spoken_languages': '[{"iso_639_1": "en", "name": "English"}, {"iso_639_1": "es", "name": "Espa\\u00f1ol"}]',
#  'status': 'Released',
#  'tagline': 'Enter the World of Pandora.',
#  'title': 'Avatar',
#  'vote_average': '7.2',
#  'vote_count': '11800'}
